# %% [markdown]
# <a href="https://colab.research.google.com/github/PeiYuJi/tibame/blob/main/tibame_20250423.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 隱藏網址:
#     - 其實不只一個網址構成, 是由無數網址構成, 那找到你需要的那個網址很重要
#     - F12
#     - 更多工具->開發工具人員
# 2. 網址參數
#     - 在?後面   參數名=值&參數名=值&...
#
#
# WIN: -headers "Origin: https://ani.gamer.com.tw" -i "" anime.mp4
#
# MAC: -headers 'Origin: https://ani.gamer.com.tw' -i '' anime.mp4
#
# ffmpeg(用拉的) 複製並且把-i後面的""填入m3u8
#
# list+dict: JSON格式
#
# 台北所有的展覽:
# [
#     {
#         "展覽地點":[
#             {"名稱":"sxss"}
#         ]
#     }
# ]
#
# 標準表格格式: CSV TSV
# (comma-separated values)
# (tab-separated values)
#
# 姓名,身高
# Elwing,175
# Bob,180
# "Elwing, Mr. Chou", 180

# %% [markdown]
# -headers "Origin: https://ani.gamer.com.tw" -i "https://bahamut.akamaized.net/113448d622788e8a4ee3fe459387b2eab9bb86a1/360p/hdntl=exp=1746020317~acl=%2f113448d622788e8a4ee3fe459387b2eab9bb86a1%2fplaylist_guest.m3u8!%2f113448d622788e8a4ee3fe459387b2eab9bb86a1%2f360p%2f*~data=hdntl,3d25f46ebcd93af%3a36632%3a0%3a1%3a52525229%3a0~hmac=df8473abac105e796ebc56e06764c293050709c9dd7f4ccf2f4a9787f3b36abf/chunklist_b400000.m3u8" anime.mp4

# %% [markdown]
# https://ani.gamer.com.tw/

# %%
# 寫入檔案/讀取檔案的複習
f = open("a.txt", "w", encoding="utf-8")
f.write("abcd")
f.close()

f = open("a.txt", "r", encoding="utf-8")
content = f.read()
print(content)
f.close()
# Out:
# abcd

# %%
import json
import urllib.request as req

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36632&geo=TW%2CHK"
f = req.urlopen(url)
content = f.read()
# content是bytes(原始的字串 0101構成)
# print(type(content))
# 型態轉換: bytes -> list+dict型態
content_convert = json.loads(content)
# print(type(content_convert))
# dict
data = content_convert["data"]
# print(data)
# list
danmu_list = data["danmu"]
# print(danmu_list)
# 儲存
f = open("chiikawa.tsv", "w", encoding="utf-8")
# 第一欄的欄位名稱
# \t -> tab
# \n -> 換行
f.write("uid\tdanmu\n")

# dict
for danmu in danmu_list:
    danmu_uid = danmu["userid"]
    danmu_text = danmu["text"]
    print(danmu_uid, danmu_text)
    line = '"{}"\t"{}"\n'.format(danmu_uid, danmu_text)
    f.write(line)
f.close()

# %%
'""'
"''"

# %%
"afdsf{a}afwerq{b}".format(a=12, b=34)
# Out:
# 'afdsf12afwerq34'

# %%
a = 5
b = 3
f"{a}-{b}"
# Out:
# '5-3'

# %%
# 寫入檔案/讀取檔案的複習
with open("a.txt", "w", encoding="utf-8") as f:
    f.write("abcd")

with open("a.txt", "r", encoding="utf-8") as f:
    content = f.read()
    print(content)
# Out:
# abcd

# %%
# 表格相關
# ! -> 命令列指令
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
students = [
    {"姓名":"Elwing", "身高":175},
    {"姓名":"Bob", "身高":180}
]
# pd表格型態: DataFrame
pd.json_normalize(students)
# Out:
#        姓名   身高
# 0  Elwing  175
# 1     Bob  180

# %%
import json
import urllib.request as req
import pandas as pd

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36632&geo=TW%2CHK"
f = req.urlopen(url)
content = f.read()

content_convert = json.loads(content)
data = content_convert["data"]
danmu_list = data["danmu"]

df = pd.json_normalize(danmu_list)
df.to_csv("chiikawa_2.tsv", sep="\t", encoding="utf-8")
# 如果你存的時候不需要預設的列標籤: index=False
df.to_csv("chiikawa_2.csv", encoding="utf-8")
df.to_csv("chiikawa.csv", encoding="utf-8")
df.to_excel("chiikawa_2.xlsx")

# %%
import pandas as pd
# 如果有列標籤, 要多帶 index_col
pd.read_csv("chiikawa.csv", encoding="utf-8", index_col=0)
# Out:
#         text    color  size  position  time        sn      userid
# 0     謝謝巴哈大哥  #FFFFFF     1         0     0  37089407     s970446
# 1        第一次  #FFFFFF     1         0     0  39557840   wex690825
# 2        0.0  #FFFFFF     1         0     0  40729192   z80262001
# 3          耶  #FFFFFF     1         0     0  41875955   ouyang318
# 4         二刷  #FFFFFF     1         0     0  42903755  qaz1210731
# ..       ...      ...   ...       ...   ...       ...         ...
# 492      ZMB  #FFFFFF     1         0   877  42527612     ZED8090
# 493  兄弟有事請轉身  #FFFFFF     1         0   890  44754781    D0690422
# 494        😀  #00C3FC     1         0   898  40894473   kekerry75
# 495   沒了？？？？  #FFFFFF     1         0   901  42188563      linzzi
# 496        哈  #FF0026     1         0   901  44529579   st5109185
#
# [497 rows x 7 columns]
